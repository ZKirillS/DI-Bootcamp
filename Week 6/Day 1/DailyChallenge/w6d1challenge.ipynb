# %% [markdown]
# # Daily Challenge: NumPy, Pandas, and Matplotlib Integration

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

city = ["New York", "Los Angeles", "Chicago", "Houston", "Phoenix",
        "Philadelphia", "San Antonio", "San Diego", "Dallas", "San Jose"]
months = ["January", "February", "March", "April", "May", "June",
         "July", "August", "September", "October", "November", "December"]
temperature = np.random.uniform(-5,35, size =(len(city),len(months)))

df = pd.DataFrame(data=temperature, index=city, columns=months)
print(df)
# Out:
#                 January   February      March      April        May  \
# New York      -2.523397  32.762737   4.482436  15.260068   6.628412
# Los Angeles   29.632381  13.502973  19.910651  -2.412881  24.364935
# Chicago        8.104863  26.756150   9.556072  -1.698293  -1.530348
# Houston       17.958850  23.797196  18.130462  31.818317   5.890212
# Phoenix       -1.464460   2.650254  25.927889  30.565789  19.107637
# Philadelphia  -0.503645  33.017526  26.223564   7.963572  -0.393609
# San Antonio   -2.398811  32.559289  18.453150  32.165315  15.908495
# San Diego     17.837287   4.572584   2.941198  12.541506  17.750743
# Dallas        34.193098  13.137538  24.438509  33.071611  25.070092
# San Jose      15.901717  20.062921  22.337146  16.618730  -2.394593
#
#                    June       July     August  September    October  \
# New York      21.744359  18.980184  -3.781519  33.252795  34.319873
# Los Angeles   22.950925  34.685303  15.536746   0.374425  26.255418
# ...

# %%
temp_avg = df.mean(axis=1)
temp_avg_sorted = temp_avg.sort_values(ascending=False)
print(temp_avg_sorted)
# Out:
# San Antonio     18.118207
# Los Angeles     18.012733
# San Jose        17.846751
# Phoenix         17.565227
# Dallas          16.398780
# New York        16.214704
# Philadelphia    15.109485
# San Diego       14.013843
# Houston         13.582420
# Chicago         11.106736
# dtype: float64

# %%
temp_high = temp_avg.idxmax()
temp_low = temp_avg.idxmin()
print(temp_high)
print(temp_low)
# Out:
# San Antonio
# Chicago

# %%
df['Temp AVG']= temp_avg
plt.figure(figsize=(10,8))
plt.plot(df.columns, df.loc[temp_high], color='red')
plt.plot(df.columns, df.loc[temp_low], color='blue')
plt.title('Monthly Temp Trends for Chicago and San Antonio', fontsize=16)
plt.xlabel('Month', fontsize=12)
plt.xticks(rotation=45)
plt.ylabel('Temperature (°C)', fontsize=12)
plt.grid(True, color = 'black', linestyle='--', linewidth =0.3, alpha=0.7)
plt.show()

# %% [markdown]
# in cities with the lowest and highest average temperatures there is no order in temperature changes, it jumps from high to low from month to month

# %%
plt.figure(figsize=(12, 6))

for city in df.index.unique():
    plt.plot(df.columns, df.loc[city], label=city)

plt.title('Monthly Temp Trends for each City', fontsize=16)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Temperature (°C)', fontsize=12)
plt.grid(True, color = 'black', linestyle='--', linewidth =0.3, alpha=0.7)
plt.legend(loc='lower left')

plt.show()

# %% [markdown]
# the lowest temperature was observed in Dallas in November (-4.97), the highest in Los Angeles in July (34.68). The highest average temperature is in San Antonio (11.18), the lowest average in Chicago (11.1). In all cities, the temperature is different throughout the year and there is no city with a smooth trend in temperature changes from low to medium and from medium to high and back
