# %%
# Exercise 1 : Matrix Operations
import numpy as np

matrix = np.array([[10,25,34],[41,53,67],[72,88,96]])
matrix
# Out:
# array([[10, 25, 34],
#        [41, 53, 67],
#        [72, 88, 96]])

# %%
determinant = np.linalg.det(matrix)
determinant
# Out:
# 7047.999999999992

# %%
inverse = np.linalg.inv(matrix)
inverse
# Out:
# array([[-0.11464245,  0.08399546, -0.0180193 ],
#        [ 0.12599319, -0.21112372,  0.10272418],
#        [-0.02951192,  0.13053348, -0.07023269]])

# %%
# Exercise 2 : Statistical Analysis
#Using NumPy, generate an array of 50 random numbers and compute:
#The mean and median.
#The standard deviation.
random_array = np.random.rand(50)
print(random_array)
print(f'Mean: {random_array.mean()}')
print(f'Median: {np.median(random_array)}')
print(f'Standart deviation: {random_array.std()}')
# Out:
# [0.77182241 0.56278332 0.35413171 0.38533885 0.93177804 0.50777024
#  0.96924443 0.73291754 0.38602595 0.52444651 0.3679266  0.52226335
#  0.31297454 0.17748153 0.42572412 0.65174216 0.72780521 0.65883684
#  0.9473486  0.81144323 0.53842289 0.0418399  0.92684089 0.39287141
#  0.20771286 0.52563374 0.69409888 0.46514475 0.07035897 0.00176653
#  0.54368816 0.9408296  0.24696242 0.93502764 0.60315903 0.2672898
#  0.55557821 0.57318844 0.46914093 0.3868477  0.70885935 0.48618414
#  0.21156646 0.02367159 0.75745513 0.8938586  0.58507587 0.70838543
#  0.27328909 0.26971016]
# Mean: 0.5206852745617301
# Median: 0.5250401263122142
# Standart deviation: 0.25903184937525053

# %%
# Exercise 3 : Date Manipulation
dates = np.arange('2023-01-01', '2023-02-01', dtype='datetime64[D]')
dates
# Out:
# array(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#        '2023-01-05', '2023-01-06', '2023-01-07', '2023-01-08',
#        '2023-01-09', '2023-01-10', '2023-01-11', '2023-01-12',
#        '2023-01-13', '2023-01-14', '2023-01-15', '2023-01-16',
#        '2023-01-17', '2023-01-18', '2023-01-19', '2023-01-20',
#        '2023-01-21', '2023-01-22', '2023-01-23', '2023-01-24',
#        '2023-01-25', '2023-01-26', '2023-01-27', '2023-01-28',
#        '2023-01-29', '2023-01-30', '2023-01-31'], dtype='datetime64[D]')

# %%
formatted_dates = [np.datetime_as_string(d, unit = 'D') for d in dates]
formatted_dates
# Out:
# ['2023-01-01',
#  '2023-01-02',
#  '2023-01-03',
#  '2023-01-04',
#  '2023-01-05',
#  '2023-01-06',
#  '2023-01-07',
#  '2023-01-08',
#  '2023-01-09',
#  '2023-01-10',
#  '2023-01-11',
#  '2023-01-12',
#  '2023-01-13',
#  '2023-01-14',
#  '2023-01-15',
#  '2023-01-16',
#  '2023-01-17',
#  '2023-01-18',
#  '2023-01-19',
#  '2023-01-20',
#  '2023-01-21',
#  '2023-01-22',
#  '2023-01-23',
#  '2023-01-24',
#  '2023-01-25',
#  '2023-01-26',
#  '2023-01-27',
#  '2023-01-28',
#  '2023-01-29',
#  '2023-01-30',
#  '2023-01-31']

# %%
# Exercise 4 : Data Manipulation with NumPy and Pandas
import pandas as pd

data = pd.DataFrame(np.random.rand(20,5))
data
# Out:
#            0         1         2         3         4
# 0   0.980824  0.874899  0.624244  0.129130  0.432797
# 1   0.803163  0.907516  0.782203  0.510703  0.827779
# 2   0.496607  0.581591  0.197990  0.890514  0.839876
# 3   0.190847  0.197981  0.342946  0.208447  0.434099
# 4   0.708703  0.487979  0.713050  0.473526  0.582500
# 5   0.878888  0.138152  0.437757  0.363324  0.026401
# 6   0.190978  0.543908  0.165409  0.747184  0.556972
# 7   0.790276  0.897733  0.604758  0.916206  0.036340
# 8   0.887958  0.061641  0.475832  0.997511  0.356174
# 9   0.041521  0.502282  0.668379  0.308659  0.122624
# 10  0.199331  0.221930  0.569579  0.205639  0.510464
# 11  0.486462  0.016605  0.846043  0.358856  0.947422
# 12  0.830236  0.489981  0.785580  0.031847  0.958875
# 13  0.752628  0.988175  0.659071  0.079106  0.556484
# 14  0.843689  0.738155  0.574124  0.413154  0.201236
# 15  0.201591  0.219908  0.585971  0.418842  0.328907
# 16  0.831025  0.430824  0.922854  0.197227  0.558844
# ...

# %%
data['Sum'] = data.sum(axis=1)

# %%
data['AVG'] = data.mean(axis=1)
data
# Out:
#            0         1         2         3         4      Mean       Sum  \
# 0   0.980824  0.874899  0.624244  0.129130  0.432797  0.608379  7.300546
# 1   0.803163  0.907516  0.782203  0.510703  0.827779  0.766273  9.195272
# 2   0.496607  0.581591  0.197990  0.890514  0.839876  0.601316  7.215788
# 3   0.190847  0.197981  0.342946  0.208447  0.434099  0.274864  3.298368
# 4   0.708703  0.487979  0.713050  0.473526  0.582500  0.593152  7.117820
# 5   0.878888  0.138152  0.437757  0.363324  0.026401  0.368904  4.426852
# 6   0.190978  0.543908  0.165409  0.747184  0.556972  0.440890  5.290684
# 7   0.790276  0.897733  0.604758  0.916206  0.036340  0.649063  7.788750
# 8   0.887958  0.061641  0.475832  0.997511  0.356174  0.555823  6.669879
# 9   0.041521  0.502282  0.668379  0.308659  0.122624  0.328693  3.944317
# 10  0.199331  0.221930  0.569579  0.205639  0.510464  0.341389  4.096663
# 11  0.486462  0.016605  0.846043  0.358856  0.947422  0.531077  6.372930
# ...

# %%
print(data['Mean'])
# Out:
# 0     0.608379
# 1     0.766273
# 2     0.601316
# 3     0.274864
# 4     0.593152
# 5     0.368904
# 6     0.440890
# 7     0.649063
# 8     0.555823
# 9     0.328693
# 10    0.341389
# 11    0.531077
# 12    0.619304
# 13    0.607093
# 14    0.554072
# 15    0.351044
# 16    0.588155
# 17    0.391862
# 18    0.559076
# 19    0.591293
# Name: Mean, dtype: float64

# %%
# Exercise 5 : Image Representation
import matplotlib.pyplot as plt

height, width = 5, 5
gray_image = np.zeros((height, width), dtype = np.uint8)
for i in range(height):
  for j in range(width):
    gray_image[i,j] = 255 - int((i+j)/(height + width -2)*255)

plt.imshow(gray_image, cmap='gray', vmin=0, vmax=255)
plt.title("Grayscale image")
plt.axis('off')
plt.show()

# %%
# Exercise 6 : Basic Hypothesis Testing
import numpy as np

# Productivity scores of employees before the training program
productivity_before = np.random.normal(loc=50, scale=10, size=30)

# Productivity scores of the same employees after the training program
productivity_after = productivity_before + np.random.normal(loc=5, scale=3, size=30)

# Your task is to formulate a hypothesis regarding the training program's effectiveness
# and test it using basic statistical functions in NumPy.
df = pd.DataFrame({'Before': productivity_before, 'After': productivity_after})

# Null Hypothesis (H0): productivity score before is bigger then after
# Alternative Hypothesis (H1): productivity score before is smaller then after

from scipy import stats
t_statistic, p_value = stats.ttest_rel(productivity_before, productivity_after)
print(f"T-statistic: {t_statistic}")
print(f"P-value: {p_value}")
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject the null hypothesis")
else:
    print("Fail to reject the null hypothesis")
# Out:
# T-statistic: -7.77303356906428
# P-value: 1.427551943087377e-08
# Reject the null hypothesis

# %%
# Exercise 7 : Complex Array Comparison
array_1 = np.array([[10,22,34],[45,56,69],[70,82,91]])
array_2 = np.array([[95,28,27],[46,52,48],[33,72,98]])
output = array_1 > array_2
output
# Out:
# array([[False, False,  True],
#        [False,  True,  True],
#        [ True,  True, False]])

# %%
# Exercise 8 : Time Series Data Manipulation
dates = np.arange('2023-01-01', '2024-01-01', dtype='datetime64[D]')

# %%
#January to March
dates_1 = dates[:90]
dates_1
# Out:
# array(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#        '2023-01-05', '2023-01-06', '2023-01-07', '2023-01-08',
#        '2023-01-09', '2023-01-10', '2023-01-11', '2023-01-12',
#        '2023-01-13', '2023-01-14', '2023-01-15', '2023-01-16',
#        '2023-01-17', '2023-01-18', '2023-01-19', '2023-01-20',
#        '2023-01-21', '2023-01-22', '2023-01-23', '2023-01-24',
#        '2023-01-25', '2023-01-26', '2023-01-27', '2023-01-28',
#        '2023-01-29', '2023-01-30', '2023-01-31', '2023-02-01',
#        '2023-02-02', '2023-02-03', '2023-02-04', '2023-02-05',
#        '2023-02-06', '2023-02-07', '2023-02-08', '2023-02-09',
#        '2023-02-10', '2023-02-11', '2023-02-12', '2023-02-13',
#        '2023-02-14', '2023-02-15', '2023-02-16', '2023-02-17',
#        '2023-02-18', '2023-02-19', '2023-02-20', '2023-02-21',
#        '2023-02-22', '2023-02-23', '2023-02-24', '2023-02-25',
#        '2023-02-26', '2023-02-27', '2023-02-28', '2023-03-01',
# ...

# %%
# April to June
dates_2 = dates[90:181]
dates_2
# Out:
# array(['2023-04-01', '2023-04-02', '2023-04-03', '2023-04-04',
#        '2023-04-05', '2023-04-06', '2023-04-07', '2023-04-08',
#        '2023-04-09', '2023-04-10', '2023-04-11', '2023-04-12',
#        '2023-04-13', '2023-04-14', '2023-04-15', '2023-04-16',
#        '2023-04-17', '2023-04-18', '2023-04-19', '2023-04-20',
#        '2023-04-21', '2023-04-22', '2023-04-23', '2023-04-24',
#        '2023-04-25', '2023-04-26', '2023-04-27', '2023-04-28',
#        '2023-04-29', '2023-04-30', '2023-05-01', '2023-05-02',
#        '2023-05-03', '2023-05-04', '2023-05-05', '2023-05-06',
#        '2023-05-07', '2023-05-08', '2023-05-09', '2023-05-10',
#        '2023-05-11', '2023-05-12', '2023-05-13', '2023-05-14',
#        '2023-05-15', '2023-05-16', '2023-05-17', '2023-05-18',
#        '2023-05-19', '2023-05-20', '2023-05-21', '2023-05-22',
#        '2023-05-23', '2023-05-24', '2023-05-25', '2023-05-26',
#        '2023-05-27', '2023-05-28', '2023-05-29', '2023-05-30',
# ...

# %%
# July to September
dates_3 = dates[181:273]
dates_3
# Out:
# array(['2023-07-01', '2023-07-02', '2023-07-03', '2023-07-04',
#        '2023-07-05', '2023-07-06', '2023-07-07', '2023-07-08',
#        '2023-07-09', '2023-07-10', '2023-07-11', '2023-07-12',
#        '2023-07-13', '2023-07-14', '2023-07-15', '2023-07-16',
#        '2023-07-17', '2023-07-18', '2023-07-19', '2023-07-20',
#        '2023-07-21', '2023-07-22', '2023-07-23', '2023-07-24',
#        '2023-07-25', '2023-07-26', '2023-07-27', '2023-07-28',
#        '2023-07-29', '2023-07-30', '2023-07-31', '2023-08-01',
#        '2023-08-02', '2023-08-03', '2023-08-04', '2023-08-05',
#        '2023-08-06', '2023-08-07', '2023-08-08', '2023-08-09',
#        '2023-08-10', '2023-08-11', '2023-08-12', '2023-08-13',
#        '2023-08-14', '2023-08-15', '2023-08-16', '2023-08-17',
#        '2023-08-18', '2023-08-19', '2023-08-20', '2023-08-21',
#        '2023-08-22', '2023-08-23', '2023-08-24', '2023-08-25',
#        '2023-08-26', '2023-08-27', '2023-08-28', '2023-08-29',
# ...

# %%
# October to December
dates_4 = dates[273:]
dates_4
# Out:
# array(['2023-10-01', '2023-10-02', '2023-10-03', '2023-10-04',
#        '2023-10-05', '2023-10-06', '2023-10-07', '2023-10-08',
#        '2023-10-09', '2023-10-10', '2023-10-11', '2023-10-12',
#        '2023-10-13', '2023-10-14', '2023-10-15', '2023-10-16',
#        '2023-10-17', '2023-10-18', '2023-10-19', '2023-10-20',
#        '2023-10-21', '2023-10-22', '2023-10-23', '2023-10-24',
#        '2023-10-25', '2023-10-26', '2023-10-27', '2023-10-28',
#        '2023-10-29', '2023-10-30', '2023-10-31', '2023-11-01',
#        '2023-11-02', '2023-11-03', '2023-11-04', '2023-11-05',
#        '2023-11-06', '2023-11-07', '2023-11-08', '2023-11-09',
#        '2023-11-10', '2023-11-11', '2023-11-12', '2023-11-13',
#        '2023-11-14', '2023-11-15', '2023-11-16', '2023-11-17',
#        '2023-11-18', '2023-11-19', '2023-11-20', '2023-11-21',
#        '2023-11-22', '2023-11-23', '2023-11-24', '2023-11-25',
#        '2023-11-26', '2023-11-27', '2023-11-28', '2023-11-29',
# ...

# %%
dates = np.arange('2023-08-01', '2024-12-15', dtype='datetime64[D]')
dates_oktober = dates[61:92]
dates_oktober
# Out:
# array(['2023-10-01', '2023-10-02', '2023-10-03', '2023-10-04',
#        '2023-10-05', '2023-10-06', '2023-10-07', '2023-10-08',
#        '2023-10-09', '2023-10-10', '2023-10-11', '2023-10-12',
#        '2023-10-13', '2023-10-14', '2023-10-15', '2023-10-16',
#        '2023-10-17', '2023-10-18', '2023-10-19', '2023-10-20',
#        '2023-10-21', '2023-10-22', '2023-10-23', '2023-10-24',
#        '2023-10-25', '2023-10-26', '2023-10-27', '2023-10-28',
#        '2023-10-29', '2023-10-30', '2023-10-31'], dtype='datetime64[D]')

# %%
december_13 = dates[134]
december_13
# Out:
# numpy.datetime64('2023-12-13')

# %%
# Exercise 9 : Data Conversion
dates_df = pd.DataFrame({'Date': dates})
dates_df
# Out:
#           Date
# 0   2023-08-01
# 1   2023-08-02
# 2   2023-08-03
# 3   2023-08-04
# 4   2023-08-05
# ..         ...
# 497 2024-12-10
# 498 2024-12-11
# 499 2024-12-12
# 500 2024-12-13
# 501 2024-12-14
#
# [502 rows x 1 columns]

# %%
random_df = pd.DataFrame({'Number':random_array})
random_df
# Out:
#       Number
# 0   0.771822
# 1   0.562783
# 2   0.354132
# 3   0.385339
# 4   0.931778
# 5   0.507770
# 6   0.969244
# 7   0.732918
# 8   0.386026
# 9   0.524447
# 10  0.367927
# 11  0.522263
# 12  0.312975
# 13  0.177482
# 14  0.425724
# 15  0.651742
# 16  0.727805
# 17  0.658837
# 18  0.947349
# 19  0.811443
# 20  0.538423
# 21  0.041840
# 22  0.926841
# 23  0.392871
# 24  0.207713
# 25  0.525634
# 26  0.694099
# 27  0.465145
# 28  0.070359
# 29  0.001767
# 30  0.543688
# 31  0.940830
# 32  0.246962
# 33  0.935028
# 34  0.603159
# 35  0.267290
# 36  0.555578
# 37  0.573188
# 38  0.469141
# 39  0.386848
# 40  0.708859
# 41  0.486184
# 42  0.211566
# 43  0.023672
# 44  0.757455
# 45  0.893859
# 46  0.585076
# 47  0.708385
# 48  0.273289
# 49  0.269710

# %%
# Exercise 10 : Basic Visualization
import matplotlib.pyplot as plt
random_df.plot(kind='bar', color = 'orange')
plt.title('Random Numbers')
plt.xlabel('Index')
plt.ylabel('Value')
plt.xticks(rotation=70)
plt.grid(True, linestyle = '--')
plt.show()
